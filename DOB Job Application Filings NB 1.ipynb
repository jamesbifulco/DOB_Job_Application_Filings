# %%
import pandas as pd

# %%
data_df = pd.read_csv("DOB_Job_Application_Filings.csv", sep = ',', engine = 'python')

# %%
data_df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-fba8f0a48a6c> in <module>
# ----> 1 data_df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
data_df.head()
# Out:
#        Job #  Doc # Borough House #      Street Name  Block    Lot    Bin #  \
# 0  440673497      1  QUEENS  215-02        93 AVENUE  10618  00028  4226672
# 1  440673512      1  QUEENS   10040       222 STREET  10780  00019  4231025
# 2  421133972      2  QUEENS   88-36     139TH STREET  09620  00033  4623670
# 3  421133972      3  QUEENS   88-36     139TH STREET  09620  00033  4623670
# 4  210182309      2   BRONX      97  WEST 169 STREET  02519  00027  2130622
#
#   Job Type Job Status  ... SPECIAL_ACTION_STATUS SPECIAL_ACTION_DATE  \
# 0       A2          R  ...                     N                 NaN
# 1       A2          R  ...                     N                 NaN
# 2       NB          P  ...                     N                 NaN
# 3       NB          P  ...                     N                 NaN
# 4       NB          P  ...                     N                 NaN
#
#   BUILDING_CLASS JOB_NO_GOOD_COUNT GIS_LATITUDE GIS_LONGITUDE  \
# ...

# %%
print(data_df.columns)
# Out:
# Index(['Job #', 'Doc #', 'Borough', 'House #', 'Street Name', 'Block', 'Lot',
#        'Bin #', 'Job Type', 'Job Status', 'Job Status Descrp',
#        'Latest Action Date', 'Building Type', 'Community - Board', 'Cluster',
#        'Landmarked', 'Adult Estab', 'Loft Board', 'City Owned', 'Little e',
#        'PC Filed', 'eFiling Filed', 'Plumbing', 'Mechanical', 'Boiler',
#        'Fuel Burning', 'Fuel Storage', 'Standpipe', 'Sprinkler', 'Fire Alarm',
#        'Equipment', 'Fire Suppression', 'Curb Cut', 'Other',
#        'Other Description', 'Applicant's First Name', 'Applicant's Last Name',
#        'Applicant Professional Title', 'Applicant License #',
#        'Professional Cert', 'Pre- Filing Date', 'Paid', 'Fully Paid',
#        'Assigned', 'Approved', 'Fully Permitted', 'Initial Cost',
#        'Total Est. Fee', 'Fee Status', 'Existing Zoning Sqft',
#        'Proposed Zoning Sqft', 'Horizontal Enlrgmt', 'Vertical Enlrgmt',
# ...

# %%
columns_to_drop = ['Job #','Doc #','Block','Lot','Bin #','Job Type','Latest Action Date','Cluster','Landmarked','Adult Estab', 'Loft Board', 'City Owned', 'Little e','PC Filed','eFiling Filed','Plumbing','Mechanical','Boiler',
'Fuel Burning', 'Fuel Storage', 'Standpipe', 'Sprinkler', 'Fire Alarm',
'Equipment', 'Fire Suppression', 'Curb Cut', 'Other',
'Other Description', 'Professional Cert', 'Pre- Filing Date', 'Paid', 'Fully Paid',
'Assigned', 'Approved', 'Fully Permitted', 'Initial Cost',
'Total Est. Fee', 'Fee Status', 'Horizontal Enlrgmt', 'Vertical Enlrgmt',
       'Enlargement SQ Footage', 'Street Frontage', 'Existing Dwelling Units', 'Proposed Dwelling Units',
       'Existing Occupancy', 'Proposed Occupancy', 'Site Fill', 'Zoning Dist1',
       'Zoning Dist2', 'Zoning Dist3', 'Special District 1',
       'Special District 2','Owner Type', 'Non-Profit', 'DOBRunDate', 'JOB_S1_NO', 'WITHDRAWAL_FLAG', 'SIGNOFF_DATE',
       'SPECIAL_ACTION_STATUS', 'SPECIAL_ACTION_DATE', 'BUILDING_CLASS',
       'JOB_NO_GOOD_COUNT', axis=1]
# Out:
#   File "<ipython-input-5-b73c4e06a539>", line 12
#     'JOB_NO_GOOD_COUNT', axis=1]
#                              ^
# SyntaxError: invalid syntax

# %%
data_df.drop(['Job #','Doc #','Block','Lot','Bin #','Job Type','Latest Action Date','Cluster','Landmarked','Adult Estab', 'Loft Board', 'City Owned', 'Little e','PC Filed','eFiling Filed','Plumbing','Mechanical','Boiler',
'Fuel Burning', 'Fuel Storage', 'Standpipe', 'Sprinkler', 'Fire Alarm',
'Equipment', 'Fire Suppression', 'Curb Cut', 'Other',
'Other Description', 'Professional Cert', 'Pre- Filing Date', 'Paid', 'Fully Paid',
'Assigned', 'Approved', 'Fully Permitted', 'Initial Cost',
'Total Est. Fee', 'Fee Status', 'Horizontal Enlrgmt', 'Vertical Enlrgmt',
       'Enlargement SQ Footage', 'Street Frontage', 'Existing Dwelling Units', 'Proposed Dwelling Units',
       'Existing Occupancy', 'Proposed Occupancy', 'Site Fill', 'Zoning Dist1',
       'Zoning Dist2', 'Zoning Dist3', 'Special District 1',
       'Special District 2','Owner Type', 'Non-Profit', 'DOBRunDate', 'JOB_S1_NO', 'WITHDRAWAL_FLAG', 'SIGNOFF_DATE',
       'SPECIAL_ACTION_STATUS', 'SPECIAL_ACTION_DATE', 'BUILDING_CLASS',
       'JOB_NO_GOOD_COUNT'], axis = 1)
# Out:
#           Borough House #       Street Name Job Status  \
# 0          QUEENS  215-02         93 AVENUE          R
# 1          QUEENS   10040        222 STREET          R
# 2          QUEENS   88-36      139TH STREET          P
# 3          QUEENS   88-36      139TH STREET          P
# 4           BRONX      97   WEST 169 STREET          P
# ...           ...     ...               ...        ...
# 1774828  BROOKLYN    2770      OCEAN AVENUE          X
# 1774829  BROOKLYN     313         76 STREET          R
# 1774830  BROOKLYN    1658         66 STREET          X
# 1774831  BROOKLYN     173  LEXINGTON AVENUE          Q
# 1774832  BROOKLYN      52   LOMBARDY STREET          X
#
#                        Job Status Descrp Building Type Community - Board  \
# 0        PERMIT ISSUED - ENTIRE JOB/WORK  1-2-3 FAMILY               413
# 1        PERMIT ISSUED - ENTIRE JOB/WORK  1-2-3 FAMILY               413
# 2                   PLAN EXAM - APPROVED        OTHERS               412
# ...

# %%
data_df = data_df.drop(['Job #','Doc #','Block','Lot','Bin #','Job Type','Latest Action Date','Cluster','Landmarked','Adult Estab', 'Loft Board', 'City Owned', 'Little e','PC Filed','eFiling Filed','Plumbing','Mechanical','Boiler',
'Fuel Burning', 'Fuel Storage', 'Standpipe', 'Sprinkler', 'Fire Alarm',
'Equipment', 'Fire Suppression', 'Curb Cut', 'Other',
'Other Description', 'Professional Cert', 'Pre- Filing Date', 'Paid', 'Fully Paid',
'Assigned', 'Approved', 'Fully Permitted', 'Initial Cost',
'Total Est. Fee', 'Fee Status', 'Horizontal Enlrgmt', 'Vertical Enlrgmt',
       'Enlargement SQ Footage', 'Street Frontage', 'Existing Dwelling Units', 'Proposed Dwelling Units',
       'Existing Occupancy', 'Proposed Occupancy', 'Site Fill', 'Zoning Dist1',
       'Zoning Dist2', 'Zoning Dist3', 'Special District 1',
       'Special District 2','Owner Type', 'Non-Profit', 'DOBRunDate', 'JOB_S1_NO', 'WITHDRAWAL_FLAG', 'SIGNOFF_DATE',
       'SPECIAL_ACTION_STATUS', 'SPECIAL_ACTION_DATE', 'BUILDING_CLASS',
       'JOB_NO_GOOD_COUNT'], axis = 1)

# %%
data_df.columns
# Out:
# Index(['Borough', 'House #', 'Street Name', 'Job Status', 'Job Status Descrp',
#        'Building Type', 'Community - Board', 'Applicant's First Name',
#        'Applicant's Last Name', 'Applicant Professional Title',
#        'Applicant License #', 'Existing Zoning Sqft', 'Proposed Zoning Sqft',
#        'ExistingNo. of Stories', 'Proposed No. of Stories', 'Existing Height',
#        'Proposed Height', 'Owner's First Name', 'Owner's Last Name',
#        'Owner's Business Name', 'Owner's House Number',
#        'Owner'sHouse Street Name', 'City ', 'State', 'Zip', 'Owner'sPhone #',
#        'Job Description', 'TOTAL_CONSTRUCTION_FLOOR_AREA', 'GIS_LATITUDE',
#        'GIS_LONGITUDE', 'GIS_COUNCIL_DISTRICT', 'GIS_CENSUS_TRACT',
#        'GIS_NTA_NAME', 'GIS_BIN'],
#       dtype='object')

# %%
pd.set_option('display.max_columns', None)

# %%
data_df.head()
# Out:
#   Borough House #      Street Name Job Status  \
# 0  QUEENS  215-02        93 AVENUE          R
# 1  QUEENS   10040       222 STREET          R
# 2  QUEENS   88-36     139TH STREET          P
# 3  QUEENS   88-36     139TH STREET          P
# 4   BRONX      97  WEST 169 STREET          P
#
#                  Job Status Descrp Building Type Community - Board  \
# 0  PERMIT ISSUED - ENTIRE JOB/WORK  1-2-3 FAMILY               413
# 1  PERMIT ISSUED - ENTIRE JOB/WORK  1-2-3 FAMILY               413
# 2             PLAN EXAM - APPROVED        OTHERS               412
# 3             PLAN EXAM - APPROVED        OTHERS               412
# 4             PLAN EXAM - APPROVED        OTHERS               204
#
#   Applicant's First Name Applicant's Last Name Applicant Professional Title  \
# 0                  WALID               ABDULLA                           PE
# 1                 DANIEL                DUNZIK                           RA
# ...

# %%
over_seven_stories = data_df['Proposed No. of Stories']>= 7

# %%
data_over_seven_stories = data_df[over_seven_stories]

# %%
print(data_over_seven_stories.shape)
# Out:
# (443681, 34)

# %%
print(data_over_seven_stories.head())
# Out:
#       Borough House #          Street Name Job Status  \
# 19  MANHATTAN     120           EAST 81 ST          P
# 35     QUEENS    1047    BEACH 21ST STREET          H
# 36     QUEENS    1047    BEACH 21ST STREET          H
# 43  MANHATTAN    1221  AVE OF THE AMERICAS          D
# 47     QUEENS    1047      BEACH 21 STREET          R
#
#                   Job Status Descrp Building Type Community - Board  \
# 19             PLAN EXAM - APPROVED        OTHERS               108
# 35           PLAN EXAM - IN PROCESS  1-2-3 FAMILY               414
# 36           PLAN EXAM - IN PROCESS        OTHERS               414
# 43   APPLICATION PROCESSED - ENTIRE        OTHERS               105
# 47  PERMIT ISSUED - ENTIRE JOB/WORK        OTHERS               414
#
#    Applicant's First Name Applicant's Last Name Applicant Professional Title  \
# 19                 ROBERT                MASONE                           PE
# ...

# %%
data_over_seven_stories.head()
# Out:
#       Borough House #          Street Name Job Status  \
# 19  MANHATTAN     120           EAST 81 ST          P
# 35     QUEENS    1047    BEACH 21ST STREET          H
# 36     QUEENS    1047    BEACH 21ST STREET          H
# 43  MANHATTAN    1221  AVE OF THE AMERICAS          D
# 47     QUEENS    1047      BEACH 21 STREET          R
#
#                   Job Status Descrp Building Type Community - Board  \
# 19             PLAN EXAM - APPROVED        OTHERS               108
# 35           PLAN EXAM - IN PROCESS  1-2-3 FAMILY               414
# 36           PLAN EXAM - IN PROCESS        OTHERS               414
# 43   APPLICATION PROCESSED - ENTIRE        OTHERS               105
# 47  PERMIT ISSUED - ENTIRE JOB/WORK        OTHERS               414
#
#    Applicant's First Name Applicant's Last Name Applicant Professional Title  \
# 19                 ROBERT                MASONE                           PE
# ...

# %%
print(data_over_seven_stories.shape)
# Out:
# (443681, 34)
