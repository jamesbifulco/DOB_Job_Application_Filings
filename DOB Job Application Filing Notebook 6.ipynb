# %%
import pandas as pd

# %%
df = pd.read_csv('job_market_19_21.csv', sep = ',', engine = 'python')

# %%
#Our current dataframe contains buildings in the DOB database that were fully permitted between 2019-2021 and are 
# 7 stories or higher. 
#Now to filter by New Buildings

# %%
df.head()
# Out:
#    Unnamed: 0      Job #    Borough House #       Street Name Job Type  \
# 0          47  440673610     QUEENS    1047   BEACH 21 STREET       A2
# 1          77  141001886  MANHATTAN      15    WEST 63 STREET       A3
# 2         210  123511182  MANHATTAN     270       PARK AVENUE       A2
# 3         219  123138176  MANHATTAN     821        1ST AVENUE       A2
# 4         238  123502478  MANHATTAN      38  EAST 19TH STREET       A2
#
#   Job Status                Job Status Descrp Latest Action Date  \
# 0          R  PERMIT ISSUED - ENTIRE JOB/WORK         05/19/2021
# 1          R  PERMIT ISSUED - ENTIRE JOB/WORK         05/13/2021
# 2          X                       SIGNED OFF         01/12/2021
# 3          R  PERMIT ISSUED - ENTIRE JOB/WORK         05/10/2021
# 4          X                       SIGNED OFF         04/29/2021
#
#   Building Type  ...  Owner's Last Name             Owner's Business Name  \
# ...

# %%
df = df.astype({"Job Type": str})

df.dtypes
# Out:
# Unnamed: 0                        int64
# Job #                             int64
# Borough                          object
# House #                          object
# Street Name                      object
# Job Type                         object
# Job Status                       object
# Job Status Descrp                object
# Latest Action Date               object
# Building Type                    object
# Community - Board                 int64
# Applicant's First Name           object
# Applicant's Last Name            object
# Applicant Professional Title     object
# Applicant License #               int64
# Professional Cert                object
# Fully Permitted                  object
# Existing Zoning Sqft              int64
# Proposed Zoning Sqft              int64
# ExistingNo. of Stories            int64
# Proposed No. of Stories           int64
# Existing Height                   int64
# Proposed Height                   int64
# ...

# %%
df["Job Type"]
# Out:
# 0        A2
# 1        A3
# 2        A2
# 3        A2
# 4        A2
#          ..
# 33390    A2
# 33391    A3
# 33392    A3
# 33393    A3
# 33394    A3
# Name: Job Type, Length: 33395, dtype: object

# %%
df[df['Job Type'].str.contains("NB")]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Job #, Borough, House #, Street Name, Job Type, Job Status, Job Status Descrp, Latest Action Date, Building Type, Community - Board, Applicant's First Name, Applicant's Last Name, Applicant Professional Title, Applicant License #, Professional Cert, Fully Permitted, Existing Zoning Sqft, Proposed Zoning Sqft, ExistingNo. of Stories, Proposed No. of Stories, Existing Height, Proposed Height, Owner's First Name, Owner's Last Name, Owner's Business Name, City , Owner'sPhone #, Job Description, DOBRunDate, JOB_S1_NO, GIS_LATITUDE, GIS_LONGITUDE, GIS_NTA_NAME]
# Index: []
#
# [0 rows x 34 columns]

# %%
print(df["Job Type"])
# Out:
# 0        A2
# 1        A3
# 2        A2
# 3        A2
# 4        A2
#          ..
# 33390    A2
# 33391    A3
# 33392    A3
# 33393    A3
# 33394    A3
# Name: Job Type, Length: 33395, dtype: object

# %%
df["Job Type"] == "NB"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 33390    False
# 33391    False
# 33392    False
# 33393    False
# 33394    False
# Name: Job Type, Length: 33395, dtype: bool
