# %%
import pandas as pd

# %%
df = pd.read_csv('job_market_19_21.csv', sep = ',', engine = 'python')

# %%
nineteen_start_date = "2019-01-01"

nineteen_end_date = "2019-12-31"

after_nineteen_start_date = df["Fully Permitted"] >= nineteen_start_date

before_nineteen_end_date = df["Fully Permitted"] <= nineteen_end_date

nineteen_full_year = after_nineteen_start_date & before_nineteen_end_date

nineteen_job_market = df.loc[nineteen_full_year]

nineteen_job_market.head()
# Out:
#     Unnamed: 0      Job #    Borough House #         Street Name Job Type  \
# 1            1  220152803      BRONX    1325  SOUTHERN BOULEVARD       NB
# 8            8  121187802  MANHATTAN     145          WEST 47 ST       NB
# 19          19  220617205      BRONX    2065         RYER AVENUE       NB
# 25          25  121190861  MANHATTAN     320     WEST 135 STREET       NB
# 26          26  123178499  MANHATTAN     199     CHRYSTIE STREET       NB
#
#    Job Status                Job Status Descrp Latest Action Date  \
# 1           R  PERMIT ISSUED - ENTIRE JOB/WORK         11/15/2021
# 8           R  PERMIT ISSUED - ENTIRE JOB/WORK         11/05/2021
# 19          R  PERMIT ISSUED - ENTIRE JOB/WORK         08/20/2021
# 25          R  PERMIT ISSUED - ENTIRE JOB/WORK         12/23/2019
# 26          R  PERMIT ISSUED - ENTIRE JOB/WORK         12/01/2021
#
#    Building Type  ...  Owner's Last Name             Owner's Business Name  \
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
nineteen_job_market.head()
# Out:
#     Unnamed: 0      Job #    Borough House #         Street Name Job Type  \
# 1            1  220152803      BRONX    1325  SOUTHERN BOULEVARD       NB
# 8            8  121187802  MANHATTAN     145          WEST 47 ST       NB
# 19          19  220617205      BRONX    2065         RYER AVENUE       NB
# 25          25  121190861  MANHATTAN     320     WEST 135 STREET       NB
# 26          26  123178499  MANHATTAN     199     CHRYSTIE STREET       NB
#
#    Job Status                Job Status Descrp Latest Action Date  \
# 1           R  PERMIT ISSUED - ENTIRE JOB/WORK         11/15/2021
# 8           R  PERMIT ISSUED - ENTIRE JOB/WORK         11/05/2021
# 19          R  PERMIT ISSUED - ENTIRE JOB/WORK         08/20/2021
# 25          R  PERMIT ISSUED - ENTIRE JOB/WORK         12/23/2019
# 26          R  PERMIT ISSUED - ENTIRE JOB/WORK         12/01/2021
#
#    Building Type  Community - Board Applicant's First Name  \
# 1         OTHERS                203                SUZANNA
# ...

# %%
nineteen_job_market["Fully Permitted"].max()
# Out:
# '2019-12-30'

# %%
nineteen_job_market["Fully Permitted"].min()
# Out:
# '2019-01-02'

# %%
index = nineteen_job_market.index
number_of_rows = len(index)
print(number_of_rows)
# Out:
# 248

# %%
twenty_start_date = "2020-01-01"

twenty_end_date = "2020-12-31"

after_twenty_start_date = df["Fully Permitted"] >= twenty_start_date

before_twenty_end_date = df["Fully Permitted"] <= twenty_end_date

twenty_full_year = after_twenty_start_date & before_twenty_end_date

twenty_job_market = df.loc[twenty_full_year]

twenty_job_market.head()
# Out:
#     Unnamed: 0      Job #   Borough House #      Street Name Job Type  \
# 16          16  320978064  BROOKLYN    2286   CROPSEY AVENUE       NB
# 22          22  420666032    QUEENS   29-17      40TH AVENUE       NB
# 29          29  220699705     BRONX    2086    VALENTINE AVE       NB
# 36          36  210178289     BRONX    2050  GRAND CONCOURSE       NB
# 57          57  420664855    QUEENS   95-10       218 STREET       NB
#
#    Job Status                Job Status Descrp Latest Action Date  \
# 16          R  PERMIT ISSUED - ENTIRE JOB/WORK         12/21/2020
# 22          R  PERMIT ISSUED - ENTIRE JOB/WORK         07/23/2021
# 29          R  PERMIT ISSUED - ENTIRE JOB/WORK         10/07/2021
# 36          R  PERMIT ISSUED - ENTIRE JOB/WORK         05/06/2021
# 57          R  PERMIT ISSUED - ENTIRE JOB/WORK         05/11/2021
#
#    Building Type  Community - Board Applicant's First Name  \
# 16        OTHERS                311                MICHAEL
# ...

# %%
index = twenty_job_market.index
number_of_rows = len(index)
print(number_of_rows)
# Out:
# 218

# %%
twentyone_start_date = "2021-01-01"

twentyone_end_date = "2021-12-31"

after_twentyone_start_date = df["Fully Permitted"] >= twentyone_start_date

before_twentyone_end_date = df["Fully Permitted"] <= twentyone_end_date

twentyone_full_year = after_twentyone_start_date & before_twentyone_end_date

twentyone_job_market = df.loc[twentyone_full_year]

twentyone_job_market.head()
# Out:
#    Unnamed: 0      Job #    Borough House #      Street Name Job Type  \
# 0           0  220538611      BRONX     915       ELSMERE PL       NB
# 2           2  220649706      BRONX    3923    CARPENTER AVE       NB
# 3           3  121205604  MANHATTAN     270      PARK AVENUE       NB
# 4           4  321597795   BROOKLYN     963  ATLANTIC AVENUE       NB
# 5           5  321941182   BROOKLYN    1882         BROADWAY       NB
#
#   Job Status                Job Status Descrp Latest Action Date  \
# 0          R  PERMIT ISSUED - ENTIRE JOB/WORK         11/05/2021
# 2          R  PERMIT ISSUED - ENTIRE JOB/WORK         04/29/2021
# 3          R  PERMIT ISSUED - ENTIRE JOB/WORK         11/30/2021
# 4          R  PERMIT ISSUED - ENTIRE JOB/WORK         06/22/2021
# 5          R  PERMIT ISSUED - ENTIRE JOB/WORK         05/05/2021
#
#   Building Type  Community - Board Applicant's First Name  \
# 0        OTHERS                206                 MINKUK
# ...

# %%
index = twentyone_job_market.index
number_of_rows = len(index)
print(number_of_rows)
# Out:
# 231

# %%
#Aprox 700 jobs fully permitted between 2019-2021 greater than 7 stories.

# %%
nineteen_job_market["Proposed No. of Stories"].unique()
# Out:
# array([ 8, 48, 12,  9, 14, 43,  7, 23, 10, 11, 15, 17, 19, 66, 22, 26, 33,
#        27, 56, 25, 21, 20, 35, 29, 16, 13, 38, 37, 74, 18, 24, 46, 60])

# %%
twenty_job_market["Proposed No. of Stories"].unique()
# Out:
# array([23, 10,  9, 13, 27,  7, 51, 18, 43, 35, 38, 12, 19, 29, 52,  8, 11,
#        22, 34, 24, 28, 14, 16, 31, 30, 25, 26, 60, 15, 17, 33, 57, 40, 44,
#        20])

# %%
twentyone_job_market["Proposed No. of Stories"].unique()
# Out:
# array([ 9,  7, 57, 12,  8, 34, 13, 14, 16, 17, 11, 31, 18, 24, 23, 22, 10,
#        51, 20, 15, 19, 40, 27, 30, 32, 28])

# %%
import csv

# %%
nineteen_job_market.to_csv('job_market_19.csv')

# %%
twenty_job_market.to_csv('job_market_20.csv')

# %%
twentyone_job_market.to_csv('job_market_21.csv')

# %%
#Can target the apploicants or the architects, 
#for the owner we can market to them we can provide them ssm, ssm coordinator, all these services. 
#The applicant, owner, and the contractor contact infor is valuable for us to market our services to. 
#Can potentially automate this process.
