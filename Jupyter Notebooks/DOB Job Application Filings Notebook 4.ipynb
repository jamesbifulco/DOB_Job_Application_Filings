# %%
import pandas as pd

# %%
data_df = pd.read_csv("DOB_Job_Application_Filings_NB.csv", sep = ',', engine = 'python')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
data_df.head()
# Out:
#        Job #  Doc #    Borough House #         Street Name  Block  Lot  \
# 0  220538611      1      BRONX     915          ELSMERE PL   2985   64
# 1  220152803      1      BRONX    1325  SOUTHERN BOULEVARD   2976   98
# 2  220649706      1      BRONX    3923       CARPENTER AVE   4819   13
# 3  121205604      1  MANHATTAN     270         PARK AVENUE   1283   21
# 4  321597795      1   BROOKLYN     963     ATLANTIC AVENUE   2019   80
#
#      Bin # Job Type Job Status                Job Status Descrp  \
# 0  2130498       NB          R  PERMIT ISSUED - ENTIRE JOB/WORK
# 1  2010494       NB          R  PERMIT ISSUED - ENTIRE JOB/WORK
# 2  2130529       NB          R  PERMIT ISSUED - ENTIRE JOB/WORK
# 3  1035421       NB          R  PERMIT ISSUED - ENTIRE JOB/WORK
# 4  3335119       NB          R  PERMIT ISSUED - ENTIRE JOB/WORK
#
#   Latest Action Date Building Type  Community - Board Cluster Landmarked  \
# 0         11/05/2021        OTHERS                206       N          N
# ...

# %%
df = data_df.drop(columns=['Doc #',
'Block',
"Lot",
'Bin #',
'Cluster',
'Landmarked',
'Adult Estab',
'Loft Board',
'City Owned',
'Little e',
'PC Filed', 
'eFiling Filed',
'Plumbing',
'Mechanical',
'Boiler',
'Fuel Burning',
'Fuel Storage',
'Standpipe',
'Sprinkler',
'Fire Alarm',
'Equipment',
'Fire Suppression',
'Curb Cut',
'Other',
'Other Description',
'Pre- Filing Date',
'Paid',
'Fully Paid',
'Assigned',
'Approved',
'Initial Cost',
'Total Est. Fee',
'Fee Status',
'Horizontal Enlrgmt',
'Vertical Enlrgmt',
'Enlargement SQ Footage',
'Street Frontage',
'Existing Dwelling Units',
'Proposed Dwelling Units',
'Existing Occupancy',
'Proposed Occupancy',
'Site Fill',
'Zoning Dist1',
'Zoning Dist2',
'Zoning Dist3',
'Special District 1',
'Special District 2',
'Owner Type',
'Non-Profit',
"Owner's House Number",
"Owner'sHouse Street Name",
'State',
'Zip',
'TOTAL_CONSTRUCTION_FLOOR_AREA',
'WITHDRAWAL_FLAG',
'SIGNOFF_DATE',
'SPECIAL_ACTION_STATUS',
'SPECIAL_ACTION_DATE',
'BUILDING_CLASS',
'JOB_NO_GOOD_COUNT',
'GIS_COUNCIL_DISTRICT',
'GIS_CENSUS_TRACT',
'GIS_BIN'])

# %%
df.head()
# Out:
#        Job #    Borough House #         Street Name Job Type Job Status  \
# 0  220538611      BRONX     915          ELSMERE PL       NB          R
# 1  220152803      BRONX    1325  SOUTHERN BOULEVARD       NB          R
# 2  220649706      BRONX    3923       CARPENTER AVE       NB          R
# 3  121205604  MANHATTAN     270         PARK AVENUE       NB          R
# 4  321597795   BROOKLYN     963     ATLANTIC AVENUE       NB          R
#
#                  Job Status Descrp Latest Action Date Building Type  \
# 0  PERMIT ISSUED - ENTIRE JOB/WORK         11/05/2021        OTHERS
# 1  PERMIT ISSUED - ENTIRE JOB/WORK         11/15/2021        OTHERS
# 2  PERMIT ISSUED - ENTIRE JOB/WORK         04/29/2021        OTHERS
# 3  PERMIT ISSUED - ENTIRE JOB/WORK         11/30/2021        OTHERS
# 4  PERMIT ISSUED - ENTIRE JOB/WORK         06/22/2021        OTHERS
#
#    Community - Board Applicant's First Name Applicant's Last Name  \
# ...

# %%
df['Fully Permitted'].isnull().values.any()
# Out:
# False

# %%
df = df.dropna(subset=['Fully Permitted'])

# %%
df['Fully Permitted'].isnull().values.any()
# Out:
# False

# %%
df['Fully Permitted'] = pd.to_datetime(df['Fully Permitted'], errors ="coerce", infer_datetime_format=True)

# %%
df['Fully Permitted'].iloc[1:100]
# Out:
# 1    2019-03-07
# 2    2021-03-16
# 3    2021-11-30
# 4    2021-06-22
# 5    2021-05-05
# 6    2021-10-14
# 7    2021-08-30
# 8    2019-02-11
# 9    2021-11-09
# 10   2021-04-30
# 11   2021-08-26
# 12   2021-12-09
# 13   2021-11-17
# 14   2021-10-06
# 15   2021-08-18
# 16   2020-12-21
# 17   2021-07-29
# 18   2021-05-03
# 19   2019-12-03
# 20   2021-09-15
# 21   2021-09-16
# 22   2020-05-20
# 23   2021-05-11
# 24   2021-12-30
# 25   2019-01-07
# 26   2019-01-29
# 27   2019-08-20
# 28   2021-02-28
# 29   2020-08-26
# 30   2021-02-18
# 31   2021-07-13
# 32   2021-10-01
# 33   2019-01-22
# 34   2021-05-06
# 35   2019-11-21
# 36   2020-04-17
# 37   2019-12-10
# 38   2019-08-08
# 39   2021-06-29
# 40   2021-05-05
# 41   2021-06-25
# 42   2021-09-14
# 43   2021-12-17
# 44   2021-05-28
# 45   2021-08-16
# 46   2019-08-19
# 47   2019-12-04
# 48   2021-08-06
# 49   2021-11-12
# 50   2019-09-17
# 51   2021-07-16
# 52   2021-08-25
# 53   2019-03-29
# 54   2021-05-10
# 55   2019-06-04
# ...

# %%
df['Fully Permitted'].iloc[1:1000]
# Out:
# 1     2019-03-07
# 2     2021-03-16
# 3     2021-11-30
# 4     2021-06-22
# 5     2021-05-05
# 6     2021-10-14
# 7     2021-08-30
# 8     2019-02-11
# 9     2021-11-09
# 10    2021-04-30
# 11    2021-08-26
# 12    2021-12-09
# 13    2021-11-17
# 14    2021-10-06
# 15    2021-08-18
# 16    2020-12-21
# 17    2021-07-29
# 18    2021-05-03
# 19    2019-12-03
# 20    2021-09-15
# 21    2021-09-16
# 22    2020-05-20
# 23    2021-05-11
# 24    2021-12-30
# 25    2019-01-07
# 26    2019-01-29
# 27    2019-08-20
# 28    2021-02-28
# 29    2020-08-26
# 30    2021-02-18
# 31    2021-07-13
# 32    2021-10-01
# 33    2019-01-22
# 34    2021-05-06
# 35    2019-11-21
# 36    2020-04-17
# 37    2019-12-10
# 38    2019-08-08
# 39    2021-06-29
# 40    2021-05-05
# 41    2021-06-25
# 42    2021-09-14
# 43    2021-12-17
# 44    2021-05-28
# 45    2021-08-16
# 46    2019-08-19
# 47    2019-12-04
# 48    2021-08-06
# 49    2021-11-12
# 50    2019-09-17
# 51    2021-07-16
# 52    2021-08-25
# ...

# %%
start_date = "2019-01-01"

# %%
end_date = "2021-12-31"

# %%
after_start_date = df["Fully Permitted"] >= start_date

# %%
before_end_date = df["Fully Permitted"] <= end_date

# %%
between_two_dates = after_start_date & before_end_date

# %%
filtered_dates = df.loc[between_two_dates]

# %%
filtered_dates.head()
# Out:
#        Job #    Borough House #         Street Name Job Type Job Status  \
# 0  220538611      BRONX     915          ELSMERE PL       NB          R
# 1  220152803      BRONX    1325  SOUTHERN BOULEVARD       NB          R
# 2  220649706      BRONX    3923       CARPENTER AVE       NB          R
# 3  121205604  MANHATTAN     270         PARK AVENUE       NB          R
# 4  321597795   BROOKLYN     963     ATLANTIC AVENUE       NB          R
#
#                  Job Status Descrp Latest Action Date Building Type  \
# 0  PERMIT ISSUED - ENTIRE JOB/WORK         11/05/2021        OTHERS
# 1  PERMIT ISSUED - ENTIRE JOB/WORK         11/15/2021        OTHERS
# 2  PERMIT ISSUED - ENTIRE JOB/WORK         04/29/2021        OTHERS
# 3  PERMIT ISSUED - ENTIRE JOB/WORK         11/30/2021        OTHERS
# 4  PERMIT ISSUED - ENTIRE JOB/WORK         06/22/2021        OTHERS
#
#    Community - Board Applicant's First Name Applicant's Last Name  \
# ...

# %%
index = filtered_dates.index
number_of_rows = len(index)
print(number_of_rows)
# Out:
# 697

# %%
import csv

# %%
filtered_dates.to_csv('DOB_Job_App_Filings_2019_2021.csv')

# %%
proposed_over_ten = filtered_dates['Proposed No. of Stories'] >= 10

# %%
job_market_19_21_10_plus = filtered_dates.loc[proposed_over_ten]

# %%
job_market_19_21_10_plus.head()
# Out:
#         Job #    Borough House #     Street Name Job Type Job Status  \
# 3   121205604  MANHATTAN     270     PARK AVENUE       NB          R
# 6   210182283      BRONX    2351   WALTON AVENUE       NB          R
# 8   121187802  MANHATTAN     145      WEST 47 ST       NB          R
# 10  321588545   BROOKLYN      34       UNION AVE       NB          R
# 16  320978064   BROOKLYN    2286  CROPSEY AVENUE       NB          R
#
#                   Job Status Descrp Latest Action Date Building Type  \
# 3   PERMIT ISSUED - ENTIRE JOB/WORK         11/30/2021        OTHERS
# 6   PERMIT ISSUED - ENTIRE JOB/WORK         10/14/2021        OTHERS
# 8   PERMIT ISSUED - ENTIRE JOB/WORK         11/05/2021        OTHERS
# 10  PERMIT ISSUED - ENTIRE JOB/WORK         04/30/2021        OTHERS
# 16  PERMIT ISSUED - ENTIRE JOB/WORK         12/21/2020        OTHERS
#
#     Community - Board Applicant's First Name Applicant's Last Name  \
# ...

# %%
index = job_market_19_21_10_plus.index
number_of_rows = len(index)
print(number_of_rows)
# Out:
# 267

# %%
proposed_over_seven = filtered_dates['Proposed No. of Stories'] >= 7

# %%
proposed_under_nine = filtered_dates['Proposed No. of Stories'] <= 9

# %%
btwn_seven_and_nine = proposed_over_seven & proposed_under_nine

# %%
job_market_19_21_btwn_7_and_9 = filtered_dates.loc[btwn_seven_and_nine]

# %%
index = job_market_19_21_btwn_7_and_9.index
number_of_rows = len(index)
print(number_of_rows)
# Out:
# 430

# %%
job_market_19_21_btwn_7_and_9.head()
# Out:
#        Job #   Borough House #         Street Name Job Type Job Status  \
# 0  220538611     BRONX     915          ELSMERE PL       NB          R
# 1  220152803     BRONX    1325  SOUTHERN BOULEVARD       NB          R
# 2  220649706     BRONX    3923       CARPENTER AVE       NB          R
# 4  321597795  BROOKLYN     963     ATLANTIC AVENUE       NB          R
# 5  321941182  BROOKLYN    1882            BROADWAY       NB          R
#
#                  Job Status Descrp Latest Action Date Building Type  \
# 0  PERMIT ISSUED - ENTIRE JOB/WORK         11/05/2021        OTHERS
# 1  PERMIT ISSUED - ENTIRE JOB/WORK         11/15/2021        OTHERS
# 2  PERMIT ISSUED - ENTIRE JOB/WORK         04/29/2021        OTHERS
# 4  PERMIT ISSUED - ENTIRE JOB/WORK         06/22/2021        OTHERS
# 5  PERMIT ISSUED - ENTIRE JOB/WORK         05/05/2021        OTHERS
#
#    Community - Board Applicant's First Name Applicant's Last Name  \
# ...

# %%
proposed_over_seven = filtered_dates['Proposed No. of Stories'] >= 7

# %%
#exisiting_over_seven = filtered_dates['ExistingNo. of Stories'] >= 7

# %%
#over_seven = proposed_over_seven & exisiting_over_seven

# %%
job_market_19_21 = filtered_dates.loc[proposed_over_seven]

# %%
job_market_19_21.head()
# Out:
#        Job #    Borough House #         Street Name Job Type Job Status  \
# 0  220538611      BRONX     915          ELSMERE PL       NB          R
# 1  220152803      BRONX    1325  SOUTHERN BOULEVARD       NB          R
# 2  220649706      BRONX    3923       CARPENTER AVE       NB          R
# 3  121205604  MANHATTAN     270         PARK AVENUE       NB          R
# 4  321597795   BROOKLYN     963     ATLANTIC AVENUE       NB          R
#
#                  Job Status Descrp Latest Action Date Building Type  \
# 0  PERMIT ISSUED - ENTIRE JOB/WORK         11/05/2021        OTHERS
# 1  PERMIT ISSUED - ENTIRE JOB/WORK         11/15/2021        OTHERS
# 2  PERMIT ISSUED - ENTIRE JOB/WORK         04/29/2021        OTHERS
# 3  PERMIT ISSUED - ENTIRE JOB/WORK         11/30/2021        OTHERS
# 4  PERMIT ISSUED - ENTIRE JOB/WORK         06/22/2021        OTHERS
#
#    Community - Board Applicant's First Name Applicant's Last Name  \
# ...

# %%
index = job_market_19_21.index
number_of_rows = len(index)
print(number_of_rows)
# Out:
# 697

# %%
import csv

# %%
job_market_19_21.to_csv('job_market_19_21.csv')

# %%
#Include another filter for between 7 and 9 inclusive vs 10 stories and above.

# %%
#We want our main findings to end up being: 

#In 2019 we increaesed the market share by x
#In 2020 we increased the market share by x 
#In 2021 we increased the market share by x

# %%
#Prior to legislation the total market share would have been buildings 10 stories and above 
#Post legislation, the market share includes buildings 7 to 9.

# %%
#Potential clients for the new market are in 2022. 
#Rule change, safety coordinator from 6-10 and need a super from 10 and above.
